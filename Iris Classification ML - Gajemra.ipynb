# %% [markdown]
# # Name - Gajemra Chandu Harnawle

# %% [markdown]
# # Data  Science Intern @ LetsGrowMore

# %% [markdown]
# # TASK 1: Iris Flowers Classification ML Project

# %% [markdown]
# # Importing the required libraries!!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# # 1. Bar plot

# %%
sns.barplot(x="species", y='petal_length',data=df)
plt.title(label='species vs petal_length',fontsize=17,color='darkviolet')
plt.show()

sns.barplot(x="species", y='petal_width',data=df)
plt.title(label='species vs petal_width',fontsize=17,color='darkviolet')
plt.show()

sns.barplot(x="species", y='sepal_length',data=df)
plt.title(label='species vs sepal_length',fontsize=17,color='darkviolet')
plt.show()

sns.barplot(x="species", y='sepal_width',data=df)
plt.title(label='species vs sepal_width',fontsize=17,color='darkviolet')
plt.show()

# %% [markdown]
# # 2. Cat plot

# %%
sns.catplot(x = 'species', hue = 'species', kind = 'count', data=df)

# %% [markdown]
# # 3. Pair plot

# %%
sns.pairplot(data=df,kind='scatter')

# %%
sns.pairplot(df,hue='species')

# %% [markdown]
# # 4. Histogram

# %%
fig = plt.figure()

x1 = fig.add_subplot(2,2,1)
x2 = fig.add_subplot(2,2,2)
x3 = fig.add_subplot(2,2,3)
x4 = fig.add_subplot(2,2,4)

x1.hist(df['sepal_length'], color = 'skyblue')
x1.set_xlabel('sepal_length in CM')

x2.hist(df['sepal_width'], color = 'skyblue')
x2.set_xlabel('sepal_width in CM')

x3.hist(df['petal_length'], color = 'skyblue')
x3.set_xlabel('petal_length in CM')

x4.hist(df['petal_width'], color = 'skyblue')
x4.set_xlabel('petal_width in CM')

fig.set_figheight(15)
fig.set_figwidth(20)

plt.show()

# %% [markdown]
# # 5. Heat Map

# %%
corr = df.corr()
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(), annot =True, cmap= 'mako')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Splitting the Dataset into the Training Set and Test Set

# %%
A = df.drop(['species'], axis=1)

# %%
A
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
B = df['species']
x_train, x_test, y_train, y_test = train_test_split(A, B, test_size=0.30)

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
print("Accuracy of model:", model.score(x_test, y_test) * 100)
# Out:
# Accuracy of model: 95.55555555555556

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
print("Accuracy of model:", model.score(x_test, y_test) * 100)
# Out:
# Accuracy of model: 95.55555555555556

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy of model:", model.score(x_test, y_test) * 100)
# Out:
# Accuracy of model: 97.77777777777777

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy of model:", model.score(x_test, y_test) * 100)
# Out:
# Accuracy of model: 97.77777777777777
